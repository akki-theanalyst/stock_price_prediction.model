# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from sklearn.preprocessing import MinMaxScaler
import joblib  # For saving the scaler
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import tensorflow.lite as tflite
import random
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pickle
# Out:
# 2025-07-03 04:36:40.783456: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-03 04:36:40.788287: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-03 04:36:40.803324: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751517400.819440   23197 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751517400.825182   23197 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1751517400.837057   23197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751517400.837070   23197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751517400.837072   23197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1751517400.837074   23197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-03 04:36:40.841260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
SEED = 40
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# %%
def preprocess_stock_data(
    csv_path, 
    date_column='Date', 
    close_column='Close', 
    test_size=0.2, 
    validation_size=0.1,
    time_steps=60, 
    scaler_output_file='/workspaces/stock_price_prediction.model/Output/icici_scaler.pkl'
):
    """
    Prepares stock market price data for time series modeling, with training, validation, and test splits.

    Args:
        csv_path (str): Path to the CSV file containing the data.
        date_column (str): Name of the date column in the CSV.
        close_column (str): Name of the closing price column in the CSV.
        test_size (float): Proportion of the data for testing.
        validation_size (float): Proportion of the data for validation.
        time_steps (int): Number of past time steps to use for each sample.
        scaler_output_file (str): Path to save the fitted MinMaxScaler instance.

    Returns:
        X_train (numpy.ndarray): Training data (features).
        y_train (numpy.ndarray): Training labels.
        X_val (numpy.ndarray): Validation data (features).
        y_val (numpy.ndarray): Validation labels.
        X_test (numpy.ndarray): Testing data (features).
        y_test (numpy.ndarray): Testing labels.
    """
    try:
        # Load the dataset
        if not os.path.exists(csv_path):
            raise FileNotFoundError(f"CSV file not found at path: {csv_path}")

        data = pd.read_csv(csv_path, parse_dates=[date_column])
        data.sort_values(by=date_column, inplace=True)

        print(f"CSV file successfully loaded. Columns: {data.columns}")
    except Exception as e:
        raise ValueError(f"Error reading CSV file or parsing date column '{date_column}': {e}")
    
    # Validate columns
    if date_column not in data.columns or close_column not in data.columns:
        raise ValueError(f"Columns '{date_column}' or '{close_column}' not found in dataset. Available columns: {data.columns}")

    try:
        # Extract the 'close' column for scaling
        close_prices = data[close_column].values.reshape(-1, 1)
    except Exception as e:
        raise ValueError(f"Error accessing '{close_column}' column: {e}")
    
    # Scale the data
    try:
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_close = scaler.fit_transform(close_prices)

        # Save the scaler to a file
        with open(scaler_output_file, 'wb') as f:
            pickle.dump(scaler, f)
        print(f"Scaler saved to {scaler_output_file}")
    except Exception as e:
        raise IOError(f"Error during scaling or saving scaler: {e}")
    
    # Create sequences of time_steps
    X, y = [], []
    try:
        for i in range(time_steps, len(scaled_close)):
            X.append(scaled_close[i - time_steps:i])
            y.append(scaled_close[i])
    except Exception as e:
        raise ValueError(f"Error creating sequences of time_steps: {e}")
    
    X, y = np.array(X), np.array(y)
    
    # Split data into train, validation, and test sets
    try:
        total_size = len(X)
        test_size_count = int(test_size * total_size)
        validation_size_count = int(validation_size * total_size)

        train_end_idx = total_size - test_size_count - validation_size_count
        val_end_idx = total_size - test_size_count

        X_train, X_val, X_test = X[:train_end_idx], X[train_end_idx:val_end_idx], X[val_end_idx:]
        y_train, y_val, y_test = y[:train_end_idx], y[train_end_idx:val_end_idx], y[val_end_idx:]

        # Adjust splits to match desired sample sizes
        train_samples = 554
        val_samples = 55
        test_samples = 84

        X_train, y_train = X[:train_samples], y[:train_samples]
        X_val, y_val = X[train_samples:train_samples + val_samples], y[train_samples:train_samples + val_samples]
        X_test, y_test = X[train_samples + val_samples:train_samples + val_samples + test_samples], y[train_samples + val_samples:train_samples + val_samples + test_samples]
    except Exception as e:
        raise ValueError(f"Error splitting data into train, validation, and test sets: {e}")
    
    print(f"Data split: {len(X_train)} training samples, {len(X_val)} validation samples, {len(X_test)} testing samples")
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
data = "/workspaces/stock_price_prediction.model/Inputs/icici_bank_data.csv"


try:
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_stock_data(
        data, 
        date_column='Date', 
        close_column='Close', 
        test_size=0.2, 
        time_steps=60, 
        scaler_output_file='/workspaces/stock_price_prediction.model/Output/icici_scaler.pkl'
    )

    # Outputs
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    print(f"X_train shape: {X_val.shape}, y_train shape: {y_val.shape}")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
except ValueError as ve:
    print(f"ValueError: {ve}")
except Exception as e:
    print(f"Unexpected Error: {e}")
# Out:
# CSV file successfully loaded. Columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
# Scaler saved to /workspaces/stock_price_prediction.model/Output/icici_scaler.pkl
# Data split: 554 training samples, 55 validation samples, 72 testing samples
# X_train shape: (554, 60, 1), y_train shape: (554, 1)
# X_train shape: (55, 60, 1), y_train shape: (55, 1)
# X_test shape: (72, 60, 1), y_test shape: (72, 1)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (554, 60, 1)
# y_train shape: (554, 1)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import joblib
import numpy as np
import os

@tf.keras.utils.register_keras_serializable(package="Custom", name="symmetric_mean_absolute_percentage_error")
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    """
    Computes Symmetric Mean Absolute Percentage Error (SMAPE).

    Args:
        y_true: Ground truth values.
        y_pred: Predicted values.

    Returns:
        SMAPE as a TensorFlow tensor.
    """
    numerator = tf.abs(y_true - y_pred)
    denominator = (tf.abs(y_true) + tf.abs(y_pred)) / 2
    smape = tf.reduce_mean(numerator / denominator) * 100
    return smape


class StockPricePredictor_ICICI:
    def __init__(self, input_shape, learning_rate=0.0007971184552975506, num_layers=2, units=256):
        self.input_shape = input_shape  # Should be (time_steps, features)
        self.learning_rate = learning_rate
        self.num_layers = num_layers
        self.units = units
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        for i in range(self.num_layers):
            # Add RNN layers
            return_sequences = i < (self.num_layers - 1)
            model.add(SimpleRNN(self.units, activation='relu', return_sequences=return_sequences, input_shape=self.input_shape))
            model.add(Dropout(0.2))  # Regularization

        # Output layer for regression (single output: close value)
        model.add(Dense(1))

        # Compile the model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss=tf.keras.losses.MeanSquaredError(),
            metrics=[
                tf.keras.metrics.MeanAbsoluteError(),
                tf.keras.metrics.MeanAbsolutePercentageError(),
                symmetric_mean_absolute_percentage_error  # Custom SMAPE metric
            ]
        )
        return model

    def train(self, X_train, y_train, batch_size=16, epochs=50, validation_data=None, patience=15):
        """
        Trains the model with an EarlyStopping callback.
        
        Args:
            X_train: Training input data.
            y_train: Training target data.
            batch_size: Batch size for training.
            epochs: Maximum number of training epochs.
            validation_data: Tuple (X_val, y_val) for validation.
            patience: Number of epochs with no improvement after which training will be stopped.
        
        Returns:
            History object containing training details.
        """
        X_train = self._validate_and_reshape(X_train, expected_shape=(None, *self.input_shape))
        if validation_data:
            X_val = self._validate_and_reshape(validation_data[0], expected_shape=(None, *self.input_shape))
            validation_data = (X_val, validation_data[1])

        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=patience,
            restore_best_weights=True
        )

        history = self.model.fit(
            X_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=validation_data,
            callbacks=[early_stopping],
            verbose=2
        )
        return history

    def predict(self, X):
        X = self._validate_and_reshape(X, expected_shape=(None, *self.input_shape))
        return self.model.predict(X)

    def save(self, model_path):
        self.model.save(model_path)
        print(f"Model saved to {model_path}")

    @staticmethod
    def load(model_path, scaler_path):
        model = load_model(model_path, custom_objects={
            "symmetric_mean_absolute_percentage_error": symmetric_mean_absolute_percentage_error
        })
        print(f"Model loaded from {model_path}")

        scaler = joblib.load(scaler_path)
        print(f"Scaler loaded from {scaler_path}")

        return model, scaler

    def _validate_and_reshape(self, X, expected_shape):
        if len(X.shape) == 2:
            reshaped = X[..., np.newaxis]
            print(f"Reshaped input from {X.shape} to {reshaped.shape}")
            return reshaped
        elif len(X.shape) == len(expected_shape):
            print(f"Input shape is valid: {X.shape}")
            return X
        else:
            raise ValueError(f"Invalid input shape {X.shape}. Expected shape {expected_shape}.")

# %%
data = '/workspaces/stock_price_prediction.model/Inputs/icici_bank_data.csv'

# %%
if __name__ == "__main__":
    # Example input data
    input_shape = (60, 1)  # 60 time steps, 1 feature (e.g., close price)
    predictor = StockPricePredictor_ICICI(input_shape=input_shape)

    # Training
    predictor.train(X_train, y_train, validation_data=(X_val, y_val))

    # Save the model
    model_path = "/workspaces/stock_price_prediction.model/Output/stock_price_Icici_model.keras"
    scaler_path = "/workspaces/stock_price_prediction.model/Output/icici_scaler.pkl"
    predictor.save(model_path)

    # Load model and scaler for inference
    loaded_model, loaded_scaler = StockPricePredictor_ICICI.load(model_path, scaler_path)

    # Predict on test data
    predictions = loaded_model.predict(X_test)
    predictions_rescaled = loaded_scaler.inverse_transform(predictions).astype('float32')

    # Rescale test labels for evaluation (if scaled)
    y_test_rescaled = loaded_scaler.inverse_transform(y_test.reshape(-1, 1)).astype('float32')

    # Print predictions
    print("Predictions (rescaled):", predictions_rescaled.astype('float32'))

    # Evaluate metrics on test data
    metrics = loaded_model.evaluate(X_test, y_test, verbose=2)
    metric_names = loaded_model.metrics_names  # Get metric names for better interpretability

    # Display metrics
    for name, value in zip(metric_names, metrics):
        print(f"{name}: {value:.4f}")

    # Compute and display custom SMAPE manually for rescaled predictions
    smape_manual = symmetric_mean_absolute_percentage_error(y_test_rescaled, predictions_rescaled)
    print(f"SMAPE (manual, rescaled): {smape_manual.numpy():.4f}")
# Out:
# Input shape is valid: (554, 60, 1)
# Input shape is valid: (55, 60, 1)
# Epoch 1/50
# 2025-07-03 04:50:14.758145: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 35/35 - 4s - 107ms/step - loss: 0.0192 - mean_absolute_error: 0.0838 - mean_absolute_percentage_error: 20.4167 - symmetric_mean_absolute_percentage_error: 24.4458 - val_loss: 0.0111 - val_mean_absolute_error: 0.1033 - val_mean_absolute_percentage_error: 13.3573 - val_symmetric_mean_absolute_percentage_error: 14.3679
# Epoch 2/50
# 35/35 - 2s - 45ms/step - loss: 0.0029 - mean_absolute_error: 0.0415 - mean_absolute_percentage_error: 9.9346 - symmetric_mean_absolute_percentage_error: 9.9552 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283 - val_mean_absolute_percentage_error: 3.6456 - val_symmetric_mean_absolute_percentage_error: 3.7196
# Epoch 3/50
# 35/35 - 2s - 45ms/step - loss: 0.0023 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 8.9975 - symmetric_mean_absolute_percentage_error: 9.0160 - val_loss: 4.8737e-04 - val_mean_absolute_error: 0.0174 - val_mean_absolute_percentage_error: 2.2688 - val_symmetric_mean_absolute_percentage_error: 2.1746
# Epoch 4/50
# 35/35 - 3s - 79ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - mean_absolute_percentage_error: 7.9258 - symmetric_mean_absolute_percentage_error: 7.9149 - val_loss: 4.6223e-04 - val_mean_absolute_error: 0.0165 - val_mean_absolute_percentage_error: 2.1738 - val_symmetric_mean_absolute_percentage_error: 2.0172
# Epoch 5/50
# 35/35 - 2s - 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - mean_absolute_percentage_error: 7.9642 - symmetric_mean_absolute_percentage_error: 8.0762 - val_loss: 8.7433e-04 - val_mean_absolute_error: 0.0244 - val_mean_absolute_percentage_error: 3.2164 - val_symmetric_mean_absolute_percentage_error: 3.0457
# Epoch 6/50
# 35/35 - 2s - 43ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - mean_absolute_percentage_error: 7.9274 - symmetric_mean_absolute_percentage_error: 7.8875 - val_loss: 8.7862e-04 - val_mean_absolute_error: 0.0251 - val_mean_absolute_percentage_error: 3.2370 - val_symmetric_mean_absolute_percentage_error: 3.2940
# Epoch 7/50
# 35/35 - 2s - 48ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - mean_absolute_percentage_error: 7.2442 - symmetric_mean_absolute_percentage_error: 7.2801 - val_loss: 4.1051e-04 - val_mean_absolute_error: 0.0153 - val_mean_absolute_percentage_error: 2.0179 - val_symmetric_mean_absolute_percentage_error: 1.8756
# Epoch 8/50
# 35/35 - 2s - 48ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - mean_absolute_percentage_error: 7.0121 - symmetric_mean_absolute_percentage_error: 7.0244 - val_loss: 5.1241e-04 - val_mean_absolute_error: 0.0188 - val_mean_absolute_percentage_error: 2.4364 - val_symmetric_mean_absolute_percentage_error: 2.4163
# Epoch 9/50
# 35/35 - 2s - 44ms/step - loss: 0.0014 - mean_absolute_error: 0.0280 - mean_absolute_percentage_error: 6.8303 - symmetric_mean_absolute_percentage_error: 6.8237 - val_loss: 4.3348e-04 - val_mean_absolute_error: 0.0169 - val_mean_absolute_percentage_error: 2.1914 - val_symmetric_mean_absolute_percentage_error: 2.1328
# Epoch 10/50
# 35/35 - 2s - 50ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - mean_absolute_percentage_error: 6.9038 - symmetric_mean_absolute_percentage_error: 6.9353 - val_loss: 4.7596e-04 - val_mean_absolute_error: 0.0167 - val_mean_absolute_percentage_error: 2.1985 - val_symmetric_mean_absolute_percentage_error: 2.0492
# Epoch 11/50
# 35/35 - 2s - 46ms/step - loss: 0.0017 - mean_absolute_error: 0.0304 - mean_absolute_percentage_error: 7.1896 - symmetric_mean_absolute_percentage_error: 7.1923 - val_loss: 7.3079e-04 - val_mean_absolute_error: 0.0230 - val_mean_absolute_percentage_error: 2.9753 - val_symmetric_mean_absolute_percentage_error: 3.0052
# Epoch 12/50
# 35/35 - 2s - 71ms/step - loss: 0.0014 - mean_absolute_error: 0.0293 - mean_absolute_percentage_error: 7.0790 - symmetric_mean_absolute_percentage_error: 7.1199 - val_loss: 6.3669e-04 - val_mean_absolute_error: 0.0203 - val_mean_absolute_percentage_error: 2.6683 - val_symmetric_mean_absolute_percentage_error: 2.5165
# Epoch 13/50
# 35/35 - 2s - 47ms/step - loss: 0.0017 - mean_absolute_error: 0.0306 - mean_absolute_percentage_error: 7.2304 - symmetric_mean_absolute_percentage_error: 7.2179 - val_loss: 3.5424e-04 - val_mean_absolute_error: 0.0152 - val_mean_absolute_percentage_error: 1.9839 - val_symmetric_mean_absolute_percentage_error: 1.8949
# Epoch 14/50
# 35/35 - 2s - 46ms/step - loss: 0.0016 - mean_absolute_error: 0.0290 - mean_absolute_percentage_error: 7.0052 - symmetric_mean_absolute_percentage_error: 7.0130 - val_loss: 0.0031 - val_mean_absolute_error: 0.0526 - val_mean_absolute_percentage_error: 6.7949 - val_symmetric_mean_absolute_percentage_error: 7.1032
# Epoch 15/50
# 35/35 - 2s - 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0282 - mean_absolute_percentage_error: 6.8218 - symmetric_mean_absolute_percentage_error: 6.8526 - val_loss: 3.2237e-04 - val_mean_absolute_error: 0.0141 - val_mean_absolute_percentage_error: 1.8408 - val_symmetric_mean_absolute_percentage_error: 1.7297
# Epoch 16/50
# 35/35 - 3s - 74ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - mean_absolute_percentage_error: 6.8367 - symmetric_mean_absolute_percentage_error: 6.8536 - val_loss: 6.7476e-04 - val_mean_absolute_error: 0.0211 - val_mean_absolute_percentage_error: 2.7735 - val_symmetric_mean_absolute_percentage_error: 2.6441
# Epoch 17/50
# 35/35 - 2s - 70ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 6.6943 - symmetric_mean_absolute_percentage_error: 6.6934 - val_loss: 0.0019 - val_mean_absolute_error: 0.0399 - val_mean_absolute_percentage_error: 5.2052 - val_symmetric_mean_absolute_percentage_error: 5.0039
# Epoch 18/50
# 35/35 - 2s - 45ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_absolute_percentage_error: 6.6787 - symmetric_mean_absolute_percentage_error: 6.7209 - val_loss: 0.0049 - val_mean_absolute_error: 0.0677 - val_mean_absolute_percentage_error: 8.8181 - val_symmetric_mean_absolute_percentage_error: 8.3779
# Epoch 19/50
# 35/35 - 2s - 48ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 6.8656 - symmetric_mean_absolute_percentage_error: 6.8779 - val_loss: 4.8948e-04 - val_mean_absolute_error: 0.0171 - val_mean_absolute_percentage_error: 2.2562 - val_symmetric_mean_absolute_percentage_error: 2.1455
# Epoch 20/50
# 35/35 - 2s - 69ms/step - loss: 0.0014 - mean_absolute_error: 0.0278 - mean_absolute_percentage_error: 6.6719 - symmetric_mean_absolute_percentage_error: 6.6852 - val_loss: 4.8878e-04 - val_mean_absolute_error: 0.0171 - val_mean_absolute_percentage_error: 2.2553 - val_symmetric_mean_absolute_percentage_error: 2.1481
# Epoch 21/50
# 35/35 - 2s - 48ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - mean_absolute_percentage_error: 6.0581 - symmetric_mean_absolute_percentage_error: 6.0511 - val_loss: 6.6362e-04 - val_mean_absolute_error: 0.0209 - val_mean_absolute_percentage_error: 2.7409 - val_symmetric_mean_absolute_percentage_error: 2.6097
# Epoch 22/50
# 35/35 - 2s - 69ms/step - loss: 0.0014 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 6.3690 - symmetric_mean_absolute_percentage_error: 6.4216 - val_loss: 0.0020 - val_mean_absolute_error: 0.0413 - val_mean_absolute_percentage_error: 5.3987 - val_symmetric_mean_absolute_percentage_error: 5.2117
# Epoch 23/50
# 35/35 - 2s - 45ms/step - loss: 0.0016 - mean_absolute_error: 0.0291 - mean_absolute_percentage_error: 6.9033 - symmetric_mean_absolute_percentage_error: 6.8627 - val_loss: 3.2141e-04 - val_mean_absolute_error: 0.0135 - val_mean_absolute_percentage_error: 1.7696 - val_symmetric_mean_absolute_percentage_error: 1.6435
# Epoch 24/50
# 35/35 - 2s - 46ms/step - loss: 9.5492e-04 - mean_absolute_error: 0.0234 - mean_absolute_percentage_error: 5.6803 - symmetric_mean_absolute_percentage_error: 5.6834 - val_loss: 2.9594e-04 - val_mean_absolute_error: 0.0131 - val_mean_absolute_percentage_error: 1.7143 - val_symmetric_mean_absolute_percentage_error: 1.5943
# Epoch 25/50
# 35/35 - 2s - 46ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - mean_absolute_percentage_error: 6.0401 - symmetric_mean_absolute_percentage_error: 6.0056 - val_loss: 4.2993e-04 - val_mean_absolute_error: 0.0173 - val_mean_absolute_percentage_error: 2.2502 - val_symmetric_mean_absolute_percentage_error: 2.2343
# Epoch 26/50
# 35/35 - 3s - 76ms/step - loss: 0.0012 - mean_absolute_error: 0.0251 - mean_absolute_percentage_error: 5.9398 - symmetric_mean_absolute_percentage_error: 5.9639 - val_loss: 3.9380e-04 - val_mean_absolute_error: 0.0150 - val_mean_absolute_percentage_error: 1.9720 - val_symmetric_mean_absolute_percentage_error: 1.8469
# Epoch 27/50
# 35/35 - 2s - 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - mean_absolute_percentage_error: 6.5676 - symmetric_mean_absolute_percentage_error: 6.5411 - val_loss: 2.9969e-04 - val_mean_absolute_error: 0.0133 - val_mean_absolute_percentage_error: 1.7376 - val_symmetric_mean_absolute_percentage_error: 1.6268
# Epoch 28/50
# 35/35 - 2s - 46ms/step - loss: 0.0013 - mean_absolute_error: 0.0255 - mean_absolute_percentage_error: 5.9080 - symmetric_mean_absolute_percentage_error: 5.8961 - val_loss: 3.1346e-04 - val_mean_absolute_error: 0.0136 - val_mean_absolute_percentage_error: 1.7821 - val_symmetric_mean_absolute_percentage_error: 1.6740
# Epoch 29/50
# 35/35 - 2s - 45ms/step - loss: 0.0015 - mean_absolute_error: 0.0281 - mean_absolute_percentage_error: 6.5104 - symmetric_mean_absolute_percentage_error: 6.6028 - val_loss: 0.0013 - val_mean_absolute_error: 0.0318 - val_mean_absolute_percentage_error: 4.1065 - val_symmetric_mean_absolute_percentage_error: 4.2175
# Epoch 30/50
# 35/35 - 2s - 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_absolute_percentage_error: 6.6017 - symmetric_mean_absolute_percentage_error: 6.5398 - val_loss: 4.2357e-04 - val_mean_absolute_error: 0.0171 - val_mean_absolute_percentage_error: 2.2287 - val_symmetric_mean_absolute_percentage_error: 2.1975
# Epoch 31/50
# 35/35 - 2s - 47ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - mean_absolute_percentage_error: 6.0747 - symmetric_mean_absolute_percentage_error: 6.1109 - val_loss: 9.5445e-04 - val_mean_absolute_error: 0.0265 - val_mean_absolute_percentage_error: 3.4815 - val_symmetric_mean_absolute_percentage_error: 3.3687
# Epoch 32/50
# 35/35 - 3s - 74ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - mean_absolute_percentage_error: 6.0253 - symmetric_mean_absolute_percentage_error: 6.0233 - val_loss: 4.9480e-04 - val_mean_absolute_error: 0.0190 - val_mean_absolute_percentage_error: 2.4642 - val_symmetric_mean_absolute_percentage_error: 2.4440
# Epoch 33/50
# 35/35 - 2s - 46ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - mean_absolute_percentage_error: 5.8245 - symmetric_mean_absolute_percentage_error: 5.8093 - val_loss: 0.0016 - val_mean_absolute_error: 0.0358 - val_mean_absolute_percentage_error: 4.6798 - val_symmetric_mean_absolute_percentage_error: 4.5244
# Epoch 34/50
# 35/35 - 2s - 46ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - mean_absolute_percentage_error: 6.1474 - symmetric_mean_absolute_percentage_error: 6.1755 - val_loss: 6.1055e-04 - val_mean_absolute_error: 0.0213 - val_mean_absolute_percentage_error: 2.7628 - val_symmetric_mean_absolute_percentage_error: 2.7645
# Epoch 35/50
# 35/35 - 2s - 45ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - mean_absolute_percentage_error: 5.8283 - symmetric_mean_absolute_percentage_error: 5.8100 - val_loss: 9.5927e-04 - val_mean_absolute_error: 0.0267 - val_mean_absolute_percentage_error: 3.4942 - val_symmetric_mean_absolute_percentage_error: 3.3747
# Epoch 36/50
# 35/35 - 2s - 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - mean_absolute_percentage_error: 6.3649 - symmetric_mean_absolute_percentage_error: 6.3437 - val_loss: 0.0027 - val_mean_absolute_error: 0.0497 - val_mean_absolute_percentage_error: 6.4245 - val_symmetric_mean_absolute_percentage_error: 6.6674
# Epoch 37/50
# 35/35 - 2s - 46ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - mean_absolute_percentage_error: 7.5912 - symmetric_mean_absolute_percentage_error: 7.5798 - val_loss: 0.0023 - val_mean_absolute_error: 0.0450 - val_mean_absolute_percentage_error: 5.8668 - val_symmetric_mean_absolute_percentage_error: 5.6621
# Epoch 38/50
# 35/35 - 2s - 49ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - mean_absolute_percentage_error: 5.9729 - symmetric_mean_absolute_percentage_error: 5.9707 - val_loss: 5.0505e-04 - val_mean_absolute_error: 0.0177 - val_mean_absolute_percentage_error: 2.3203 - val_symmetric_mean_absolute_percentage_error: 2.2488
# Epoch 39/50
# 35/35 - 2s - 68ms/step - loss: 0.0010 - mean_absolute_error: 0.0228 - mean_absolute_percentage_error: 5.3481 - symmetric_mean_absolute_percentage_error: 5.3483 - val_loss: 4.2524e-04 - val_mean_absolute_error: 0.0158 - val_mean_absolute_percentage_error: 2.0757 - val_symmetric_mean_absolute_percentage_error: 2.0078
# Model saved to /workspaces/stock_price_prediction.model/Output/stock_price_Icici_model.keras
# Model loaded from /workspaces/stock_price_prediction.model/Output/stock_price_Icici_model.keras
# Scaler loaded from /workspaces/stock_price_prediction.model/Output/icici_scaler.pkl
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2025-07-03 04:51:29.368973: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Predictions (rescaled): [[1263.4402]
#  [1262.3491]
#  [1258.5273]
#  [1254.0731]
#  [1252.1147]
#  [1258.3641]
#  [1255.9685]
#  [1246.9998]
#  [1257.8173]
#  [1255.998 ]
#  [1239.8712]
#  [1224.8782]
#  [1224.6456]
#  [1225.9662]
#  [1211.8237]
#  [1207.1056]
#  [1211.1488]
#  [1216.1265]
#  [1219.3419]
#  [1217.1443]
#  [1216.4207]
#  [1238.1339]
#  [1246.8744]
#  [1249.2577]
#  [1264.6254]
#  [1270.5786]
#  [1301.2845]
#  [1321.26  ]
#  [1337.008 ]
#  [1354.7241]
#  [1348.9583]
#  [1340.0565]
#  [1338.8187]
#  [1347.338 ]
#  [1330.1099]
#  [1328.3801]
#  [1332.2539]
#  [1334.7579]
#  [1304.5227]
#  [1296.9297]
#  [1303.6555]
#  [1310.1395]
#  [1340.3198]
#  [1355.289 ]
#  [1391.3451]
#  [1410.2126]
#  [1414.6566]
#  [1423.7174]
#  [1411.0806]
#  [1406.3663]
#  [1423.9933]
#  [1431.4229]
#  [1428.6895]
#  [1429.7988]
#  [1430.8503]
#  [1432.606 ]
#  [1435.9127]
#  [1436.835 ]
#  [1404.6158]
#  [1431.2782]
#  [1439.6896]
#  [1427.321 ]
#  [1444.6924]
#  [1453.9094]
#  [1451.7347]
#  [1442.7004]
#  [1444.1311]
#  [1445.0074]
#  [1448.8292]
#  [1458.7664]
#  [1451.6102]
#  [1452.3956]]
# 3/3 - 1s - 195ms/step - loss: 4.7915e-04 - mean_absolute_error: 0.0152 - mean_absolute_percentage_error: 1.8065 - symmetric_mean_absolute_percentage_error: 1.5684
# loss: 0.0005
# compile_metrics: 0.0152
# SMAPE (manual, rescaled): 0.9065

# %%
plt.figure(figsize=(12, 6))
plt.plot(loaded_scaler.inverse_transform(y_test.reshape(-1, 1)), label="Actual Prices", color="darkorange", alpha=0.6, linewidth=2)
plt.plot(loaded_scaler.inverse_transform(predictions.reshape(-1, 1)), label="Predicted Prices", color="#4285F4", alpha=0.6, linestyle="--", linewidth=2)
plt.title("Stock Price Prediction for Icici",fontsize = 26)
plt.xlabel("Time Steps",fontsize = 20)
plt.ylabel("Stock Price (Original Scale)",fontsize = 20)
plt.legend(fontsize = 20)
plt.grid(True)

plt.show()
